# %% [markdown]
# # Fitting TDE LCs to find g band peaks (or r band where only that is available or g is sparse)

# %% [markdown]
# From a Claude "research" request
# Method 1: Gaussian rise + power law decay
# Method 2: Localized parabolic-ish fit or low order polynomial
# Method 3: Is to do physical moddeling with MOSFIT or similar
# Fitting almost always MCMC (emcee or similar)
#
#
# From reading papers
# - Van Velzen 2017 uses a two component model (gaussian rise than exponetial or power law decay) and fits with emcee (sect 5) for a variety of parameters in addition to t_peak
# - Hammerstein 2023 uses a similar process (also section 5)
# - Yao+2023 uses a similar approach (section 3)
#
# Based on this I'm going to implement the 2 component model first

# %% [markdown]
# ## Jon figures out how code works - EMCEE Markov Chain Monte Carlo sampler

# %%
#first I need to be able to fit a piecewise equation with emcee
